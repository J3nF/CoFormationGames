# %%
using GraphRecipes, Plots
using Graphs

# %%
g = wheel_graph(3)
edgelabel_dict = Dict((1,2) => "0", (2,3) => "1", (1,3) => "1")
graphplot(g,
    x = [0, 1, 0.5],
    y = [0, 0, 1],
    names=[0,0,1], # node labels are opinions the nodes hold
    edgelabel=edgelabel_dict, # edge labels are opinion differences
    curves=false,
    nodeshape=:circle,
    nodecolor=:lightblue,
    markersize=0.15,
    fontsize=16,
)

savefig("../typst/fig/0_triangle.png")
# Out:
# "/home/jens/Documents/Repos/CoFormationGames/typst/fig/0_triangle.png"

# %%
g = path_graph(3)
edgelabel_dict = Dict((1,2) => "0", (2,3) => "1")
graphplot(g,
    x = [0, 1, 2], # position nodes in a line
    y = [0, 0, 0],
    names=[0,0,1], # node labels are opinions the nodes hold
    edgelabel=edgelabel_dict, # edge labels are opinion differences
    curves=false,
    nodeshape=:circle,
    nodecolor=:lightblue,
    markersize=0.2,
    fontsize=16,
)
savefig("../typst/fig/0_outchain.png")
# Out:
# "/home/jens/Documents/Repos/CoFormationGames/typst/fig/0_outchain.png"

# %%
g = path_graph(3)
edgelabel_dict = Dict((1,2) => "1", (2,3) => "1")
graphplot(g,
    x = [0, 1, 2], # position nodes in a line
    y = [0, 0, 0],
    names=[0,1,0], # node labels are opinions the nodes hold
    edgelabel=edgelabel_dict, # edge labels are opinion differences
    curves=false,
    nodeshape=:circle,
    nodecolor=:lightblue,
    markersize=0.2,
    fontsize=16,
)
savefig("../typst/fig/0_inchain.png")
# Out:
# "/home/jens/Documents/Repos/CoFormationGames/typst/fig/0_inchain.png"

# %%
g = path_graph(4)
edgelabel_dict = Dict((1,2) => "1", (2,3) => "0", (3,4) => "0")
graphplot(g,
    x = [0, 1, 2, 3], # position nodes in a line
    y = [0, 0, 0, 0],
    names=[1,0,0,0], # node labels are opinions the nodes hold
    edgelabel=edgelabel_dict, # edge labels are opinion differences
    curves=false,
    nodeshape=:circle,
    nodecolor=:lightblue,
    markersize=0.2,
    fontsize=16,
)

savefig("../typst/fig/1_outchain.png")
# Out:
# "/home/jens/Documents/Repos/CoFormationGames/typst/fig/1_outchain.png"

# %%
g = path_graph(4)
edgelabel_dict = Dict((1,2) => "0", (2,3) => "1", (3,4) => "0")
graphplot(g,
    x = [0, 1, 2, 3], # position nodes in a line
    y = [0, 0, 0, 0],
    names=[1,1,0,0], # node labels are opinions the nodes hold
    edgelabel=edgelabel_dict, # edge labels are opinion differences
    curves=false,
    nodeshape=:circle,
    nodecolor=:lightblue,
    markersize=0.2,
    fontsize=16,
)

savefig("../typst/fig/1_inchain.png")
# Out:
# "/home/jens/Documents/Repos/CoFormationGames/typst/fig/1_inchain.png"

# %%
g = star_graph(4)
edgelabel_dict = Dict((1,2) => "1", (1,3) => "0", (1,4) => "0")
graphplot(g,
    x = [0, 0, -1, 1],
    y = [0, 1.15, -1, -1],
    names=[0,1,0,0], # node labels are opinions the nodes hold
    edgelabel=edgelabel_dict, # edge labels are opinion differences
    curves=false,
    nodeshape=:circle,
    nodecolor=:lightblue,
    markersize=0.2,
    fontsize=16,
)

savefig("../typst/fig/1_1star.png")
# Out:
# "/home/jens/Documents/Repos/CoFormationGames/typst/fig/1_1star.png"

# %%
g = star_graph(4)
edgelabel_dict = Dict((1,2) => "0", (1,3) => "1", (1,4) => "1")
graphplot(g,
    x = [0, 0, -1, 1],
    y = [0, 1.15, -1, -1],
    names=[1,1,0,0], # node labels are opinions the nodes hold
    edgelabel=edgelabel_dict, # edge labels are opinion differences
    curves=false,
    nodeshape=:circle,
    nodecolor=:lightblue,
    markersize=0.2,
    fontsize=16,
)

savefig("../typst/fig/1_2star.png")
# Out:
# "/home/jens/Documents/Repos/CoFormationGames/typst/fig/1_2star.png"
